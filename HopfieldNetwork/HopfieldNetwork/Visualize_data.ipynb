# %%
from utilities import visualize_data

# %%
filename = "animals-14x9.csv"
height, width = 14, 9
visualize_data(filename, height, width)
# Out:
# 6

# %%
filename = "large-25x25.csv"
height, width = 25, 25
visualize_data(filename, height, width)
# Out:
# 6

# %%
filename = "large-25x25.plus.csv"
height, width = 25, 25
visualize_data(filename, height, width)
# Out:
# 15

# %%
filename = "large-25x50.csv"
height, width = 25, 50
visualize_data(filename, height, width)
# Out:
# 6

# %%
filename = "letters-14x20.csv"
height, width = 14, 20
visualize_data(filename, height, width)
# Out:
# 26

# %%
filename = "letters-abc-8x12.csv"
height, width = 8, 12
visualize_data(filename, height, width)
# Out:
# 3

# %%
filename = "OCRA-12x30-cut.csv"
height, width = 12, 30
visualize_data(filename, height, width)
# Out:
# 7

# %%
filename = "small-7x7.csv"
height, width = 7, 7
visualize_data(filename, height, width)
# Out:
# 5

# %%
len(5 * np.zeros((5, 2)))
# Out:
# 5
